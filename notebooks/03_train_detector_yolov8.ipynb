# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
model.train(
    data="Desktop/lpd/data/yolo/lpr_us_can.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name="lpr-yolov8n-us-can",
)
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (Quadro T1000 with Max-Q Design, 3716MiB)
# ...

# %%
model.train(
    data="data/yolo/lpr_us_can.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    name="lpr-yolov8n-us-can",
)
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (Quadro T1000 with Max-Q Design, 3716MiB)
# ...

# %%
from ultralytics import YOLO
from pathlib import Path

HOME = Path.home()
root = HOME / "Desktop" / "lpd"
data_yaml = root / "data" / "yolo" / "lpr_car_plate.yaml"

print("Using dataset config:", data_yaml)  # sanity check

model = YOLO("yolov8n.pt")

model.train(
    data=str(data_yaml),           # <-- absolute path
    epochs=50,
    imgsz=640,
    batch=16,
    name="lpr-car-plate-yolov8n",
)
# Out:
# Using dataset config: /home/pablo/Desktop/lpd/data/yolo/lpr_car_plate.yaml
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (Quadro T1000 with Max-Q Design, 3716MiB)
# ...

# %%
from ultralytics import YOLO
from pathlib import Path

HOME = Path.home()
root = HOME / "Desktop" / "lpd"
data_yaml = root / "data" / "yolo" / "lpr_car_plate.yaml"

print("Using dataset config:", data_yaml)  # sanity check

model = YOLO("yolov8n.pt")

model.train(
    data=str(data_yaml),           # <-- absolute path
    epochs=50,
    imgsz=640,
    batch=16,
    name="lpr-car-plate-yolov8n",
)
# Out:
# Using dataset config: /home/pablo/Desktop/lpd/data/yolo/lpr_car_plate.yaml
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.9.1+cu128 CUDA:0 (Quadro T1000 with Max-Q Design, 3716MiB)
# ...
