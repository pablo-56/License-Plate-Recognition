# %%
from pathlib import Path
from PIL import Image

# %%
us_dir = Path("data/raw/us_lp")
cp_dir = Path("data/raw/car_plate")

# %%
print("US images samples:", list(us_dir.glob("*.png"))[:5])
# Out:
# US images samples: []

# %%
print("Car-plate images samples:", list(cp_dir.glob("images/*.png"))[:5])
# Out:
# Car-plate images samples: []

# %%
Image.open(list(cp_dir.glob("images/*.png"))[0]).resize((10, 20))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Image.open(list(cp_dir.glob("images/*.png"))[0]).resize((10, 20))
#
# IndexError: list index out of range
